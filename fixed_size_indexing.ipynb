# %%
height = 512
n_hfft = 257

for i in range(n_hfft) :
    print("{}/{} : {}".format(i,n_hfft,int(((i+1)/n_hfft) * height)))
# Out:
# 0/257 : 1
# 1/257 : 3
# 2/257 : 5
# 3/257 : 7
# 4/257 : 9
# 5/257 : 11
# 6/257 : 13
# 7/257 : 15
# 8/257 : 17
# 9/257 : 19
# 10/257 : 21
# 11/257 : 23
# 12/257 : 25
# 13/257 : 27
# 14/257 : 29
# 15/257 : 31
# 16/257 : 33
# 17/257 : 35
# 18/257 : 37
# 19/257 : 39
# 20/257 : 41
# 21/257 : 43
# 22/257 : 45
# 23/257 : 47
# 24/257 : 49
# 25/257 : 51
# 26/257 : 53
# 27/257 : 55
# 28/257 : 57
# 29/257 : 59
# 30/257 : 61
# 31/257 : 63
# 32/257 : 65
# 33/257 : 67
# 34/257 : 69
# 35/257 : 71
# 36/257 : 73
# 37/257 : 75
# 38/257 : 77
# 39/257 : 79
# 40/257 : 81
# 41/257 : 83
# 42/257 : 85
# 43/257 : 87
# 44/257 : 89
# 45/257 : 91
# 46/257 : 93
# 47/257 : 95
# 48/257 : 97
# 49/257 : 99
# 50/257 : 101
# 51/257 : 103
# 52/257 : 105
# 53/257 : 107
# 54/257 : 109
# 55/257 : 111
# 56/257 : 113
# 57/257 : 115
# 58/257 : 117
# 59/257 : 119
# 60/257 : 121
# 61/257 : 123
# 62/257 : 125
# 63/257 : 127
# 64/257 : 129
# 65/257 : 131
# 66/257 : 133
# 67/257 : 135
# 68/257 : 137
# 69/257 : 139
# 70/257 : 141
# ...
